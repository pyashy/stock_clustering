# %%
from autoencoders import Conv1dAutoEncoder, LSTMAutoEncoder, TickerDataModule, MLPAutoEncoder

import pandas as pd
import numpy as np
from math import floor

# %%
model_with_time = Conv1dAutoEncoder.load_from_checkpoint(
    'autoencoder/lightning_logs/version_6/checkpoints/epoch=38-step=299051.ckpt',
    in_channels=4,
    n_latent_features=8)
model_with_time.eval();

# %%
model = MLPAutoEncoder.load_from_checkpoint('autoencoders/lightning_logs/version_22/checkpoints/epoch=99-step=70399.ckpt',
                                            in_features=30,
                                            latent_features=8)
model.eval();

# %%
df = pd.read_csv('data/ticker_data_Close.csv', index_col=[0]).dropna(axis=1).pct_change().fillna(0).T

# %%
for name_ticker in np.unique(df.index):
    ts_name = df[df.index == name_ticker]
    for i in range(floor(ts_name.shape[1] / 30)):
# Out:
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# (1, 1029)
# ...
